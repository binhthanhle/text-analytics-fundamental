# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Getting-Data" data-toc-modified-id="Getting-Data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Getting Data</a></span><ul class="toc-item"><li><span><a href="#Drop-duplicated-columns" data-toc-modified-id="Drop-duplicated-columns-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Drop duplicated columns</a></span></li><li><span><a href="#First-save-the-dataset" data-toc-modified-id="First-save-the-dataset-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>First save the dataset</a></span></li></ul></li><li><span><a href="#Data-First-Understanding" data-toc-modified-id="Data-First-Understanding-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data First Understanding</a></span></li><li><span><a href="#Data-Understanding:-data-quality-report" data-toc-modified-id="Data-Understanding:-data-quality-report-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Understanding: data quality report</a></span><ul class="toc-item"><li><span><a href="#Table-with-descriptive-statistics-for-all-the-categorical-features" data-toc-modified-id="Table-with-descriptive-statistics-for-all-the-categorical-features-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Table with descriptive statistics for all the categorical features</a></span></li><li><span><a href="#Table-with-descriptive-statistics-for-all-the-continuous-features" data-toc-modified-id="Table-with-descriptive-statistics-for-all-the-continuous-features-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Table with descriptive statistics for all the continuous features</a></span></li><li><span><a href="#Histograms-for-all-continuous-features" data-toc-modified-id="Histograms-for-all-continuous-features-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Histograms for all continuous features</a></span></li><li><span><a href="#Box-plots-for-all-the-continuous-features" data-toc-modified-id="Box-plots-for-all-the-continuous-features-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Box plots for all the continuous features</a></span></li><li><span><a href="#Bar-plots-for-all-the-categorical-features" data-toc-modified-id="Bar-plots-for-all-the-categorical-features-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Bar plots for all the categorical features</a></span></li></ul></li><li><span><a href="#Data-Understanding:-data-quality-plan" data-toc-modified-id="Data-Understanding:-data-quality-plan-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Understanding: data quality plan</a></span><ul class="toc-item"><li><span><a href="#Irregular-cardinality" data-toc-modified-id="Irregular-cardinality-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Irregular cardinality</a></span></li><li><span><a href="#Null-values" data-toc-modified-id="Null-values-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Null values</a></span></li><li><span><a href="#Outliers-(It-is-hard!-To-decice-remove-or-not-remove-those-samples)" data-toc-modified-id="Outliers-(It-is-hard!-To-decice-remove-or-not-remove-those-samples)-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Outliers (It is hard! To decice remove or not remove those samples)</a></span></li><li><span><a href="#Duplicate-rows" data-toc-modified-id="Duplicate-rows-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Duplicate rows</a></span></li></ul></li><li><span><a href="#Solutions" data-toc-modified-id="Solutions-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Solutions</a></span><ul class="toc-item"><li><span><a href="#Data-Quality-Plan" data-toc-modified-id="Data-Quality-Plan-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Data Quality Plan</a></span></li></ul></li><li><span><a href="#Save-the-Clean-data" data-toc-modified-id="Save-the-Clean-data-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Save the Clean data</a></span></li></ul></div>

# %% [markdown]
# # Exercises
#
# This Notebook aims to analyse data generated by political candidates during the Irish General Elections 2016.
# We have a CSV file describing candidates and a json file describing Twitter activity of candidates.
# The aim is to merge the 2 files into a single CSV file and produce a data quality report and a data quality plan for the merged CSV, as well as some initial interpretation of findings.  The CSV file named  **ge16-results-elected.csv**, contains data describing the candidates, e.g., name, party and constituency, and data on whether they got elected or not. The json file contains data such as the candidate name and the number of tweets issued by their Twitter account, the number of followers the Twitter account has, etc. We aim to understand this data and to look for initial evidence that candidate Twitter account details (e.g., tweets, folowers) is (or not) indicative of getting elected.
# The Notebook also contains an example solution for the practice exercises.
#
# 1. Getting Data: Download the data from Moodle. This is an archive named *Lab4-data-archive*
#     containing a file named **ge16-results-elected.csv** and a json file named: **ge16-twittercounter-candidates.json**
#
#     - Merge the 2 files (your CSV file and the json file) into a single CSV file named
#     **ge16-candidates-twitter-elected.csv**
#
#     - Only keep unique columns from each file (e.g., only one column named Party in the merged CSV file).
#     Show the first 10 rows in your resulting CSV file.
#
# 2. Data Understanding: Prepare a data quality report for your merged CSV file.
#     - Prepare a table with descriptive statistics for all the continuous features.
#     - Prepare a table with descriptive statistics for all the categorical features.
#     - Plot histograms for all the continuous features.
#     - Plot box plots for all the continuous features.
#     - Plot bar plots for all the categorical features.
#     - Save all the tables and plots into files with self-explanatory names.
#
# 3. Data Understanding: Prepare a data quality plan for the merged CSV file.
#     - Mark down all the features where there are problems.
#     - Propose solutions to deal with the problems identified.
#     - Apply your solutions to obtain a new CSV file where data quality issues were addressed.
#     Explain why did you choose one solution over (potentially many) other.
#
# 4. Data Understanding: Exploring relationships between feature pairs:
#     - Choose a subset of 10 features and plot pairwise feature interaction
#     (e.g., continuous-continuous feature plot or continuous-categorical plots). Compute correlations for the numeric features.
#     - Discuss your findings from the plots above. Do you find any features indicative of the candidate getting elected?

# %%
# Import pandas, numpy and matplotlib libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from matplotlib.backends.backend_pdf import PdfPages
# %matplotlib inline

# %% [markdown]
# ## Getting Data

# %%
# Convert csv and json files into dataframes
df1 = pd.read_csv('ge16-results-elected.csv',keep_default_na=True,sep=',\s+', delimiter=',', encoding="utf-8", skipinitialspace=True)
df1.head(10)
# Out:
#     Twitter ID   Lastname  Firstname             Fullname  Gender  Party  \
# 0  507910843.0    Haughey       Sean         Sean Haughey    Male     ff
# 1  238613047.0    O'Leary      Julie        Julie O'Leary  Female     fg
# 2   20586381.0     Cannon     Ciaran        Ciaran Cannon    Male     fg
# 3  219454029.0    O'Brien  Johnathan     Jonathan O'Brien    Male     sf
# 4   19735329.0    Donohoe    Paschal      Paschal Donohoe    Male     fg
# 5          0.0    Quigley       Adam  Kiaran Adam Quigley    Male    ind
# 6          0.0      Leahy       John           John Leahy    Male  renua
# 7   20777397.0    Doherty       Gary         Gary Doherty    Male     sf
# 8  201067717.0      Hayde   Lorraine       Lorraine Hayde  Female    ind
# 9   29110219.0  McAuliffe       Paul       Paul McAuliffe    Male     ff
#
#          Constituency  Elected  OnTwitter
# 0    Dublin Bay North        1          1
# 1  Cork North Central        0          1
# 2         Galway East        1          1
# 3  Cork North Central        1          1
# 4      Dublin Central        1          1
# 5   Dublin South West        0          0
# 6              Offaly        0          0
# 7             Donegal        0          1
# 8       Kildare South        0          1
# 9   Dublin North West        0          1

# %%
df2 = pd.read_json('ge16-twittercounter-candidates.json')
df2.head(10)
# Out:
#            constituency  day_follower_change   firstname  followers  \
# 0         Kildare South                    0       Fiona       1721
# 1       Dublin Mid-West                    0  Anne-Marie       3872
# 2       Dublin Mid-West                    0       Derek       2127
# 3                 Kerry                    0       Brian        577
# 4  Dublin South Central                    0        Eric       2305
# 5                 Kerry                    0      Arthur       2598
# 6           Galway West                   -1      Trevor       2410
# 7  Dublin South Central                    1     Michael        198
# 8       Cork South West                    0        Alan       1249
# 9    Longford Westmeath                    0       Donal         11
#
#    following                fullname          id   last_tweet  \
# 0       1727  Fiona McLoughlin Healy   274437336    1 day ago
# 1       3042      Anne-Marie McNally   252591743    1 day ago
# 2        237           Derek Keating    95884790   5 days ago
# 3        841          Brian Finucane  1510303820   3 days ago
# 4        725              Eric Byrne   236487406   3 days ago
# 5        717           Arthur Spring   116559835   5 days ago
# 6       2162   Trevor O'Clochartaigh   238633165    1 day ago
# 7        238          Michael Gargan  4362566415    1 day ago
# 8       1927            Alan Coleman  1110233430   3 days ago
# 9          0           Donal Jackson   249114962  5 years ago
#
#            lastname  overall_follower_change                 party  \
# 0  McLoughlin Healy                       51             Fine Gael
# 1           McNally                        0      Social Democrats
# 2           Keating                       90             Fine Gael
# 3          Finucane                       43  People Before Profit
# 4             Byrne                       71                Labour
# 5            Spring                       68                Labour
# 6    O'Clochartaigh                      142             Sinn Fein
# 7            Gargan                       47                 Renua
# 8           Coleman                      142     Independent/Other
# 9           Jackson                        2     Independent/Other
#
#        screen_name  tweets
# 0       fionamacky    6359
# 1       amomcnally   21353
# 2     derekkeating     427
# 3    finucanebrian     973
# 4      ericbyrnetd     480
# 5         springaj    1391
# 6       trevorocsf    2531
# 7     mgarganrenua     742
# 8  alancolemancork     665
# 9  donaljacksonirl       1

# %%
# Rename columns in df2 to match title of corresponding columns in df1 
# Why should we do this step? ==> we want to merge to dataframes with the same column "Twitter ID"
df2 = df2.rename(columns = {'id':'Twitter ID'})
df2
# Out:
#              constituency  day_follower_change   firstname  followers  \
# 0           Kildare South                    0       Fiona       1721
# 1         Dublin Mid-West                    0  Anne-Marie       3872
# 2         Dublin Mid-West                    0       Derek       2127
# 3                   Kerry                    0       Brian        577
# 4    Dublin South Central                    0        Eric       2305
# 5                   Kerry                    0      Arthur       2598
# 6             Galway West                   -1      Trevor       2410
# 7    Dublin South Central                    1     Michael        198
# 8         Cork South West                    0        Alan       1249
# 9      Longford Westmeath                    0       Donal         11
# 10        Cork North West                    0       Jason         43
# 11       Roscommon Galway                    1     Michael        801
# 12         Dublin Central                   13     Maureen       4217
# 13     Cork North Central                    1      Thomas        422
# 14         Dublin Central                    0       Diana        495
# 15       Dublin Bay North                   23      Aodhan      18094
# 16                Wexford                   38        Mick      20405
# 17        Cork South West                    1     Michael       3134
# 18        Dublin Rathdown                    0        Mary       1697
# 19                Donegal                    0       Niamh        214
# 20                Wicklow                   22     Stephen      23628
# 21         Cavan Monaghan                    0     Micheal        514
# 22          Kildare North                    1     Bernard       2936
# 23                Wexford                    0        Paul       3982
# 24       Dublin Bay North                    5     Richard       7671
# 25                  Clare                    1     Michael        842
# 26             Meath West                    0         Ray        325
# 27                  Clare                    1     Michael        411
# 28   Dublin South Central                    8        Joan       4864
# 29      Dublin North West                    5        John       9216
# ..                    ...                  ...         ...        ...
# 353               Wexford                    2     Malcolm        324
# 354         Kildare South                    0      Declan         53
# 355               Wexford                    0         Ann        267
# 356         Dublin Fingal                   -1        Tony        104
# 357         Dublin Fingal                   -1       James       8946
# 358            Meath East                    1         Ben       1560
# 359      Dublin Bay South                   -2       Kevin       5368
# 360     Dublin North West                    1      Dessie       2217
# 361     Dublin South West                    0        Mick        339
# 362       Cork North West                    0     Shirley         43
# 363     Dublin South West                    2       Sarah       3003
# 364         Kildare South                    0        Sean        495
# 365            Meath West                   -1      Seamus        610
# 366               Wicklow                    0         Pat        246
# 367             Tipperary                    1      Mattie       2308
# 368         Kildare North                    1     Brendan        582
# 369           Dublin West                    0          TJ        600
# 370                 Kerry                    1       Donal        104
# 371            Meath West                    4      Peadar       4260
# 372               Wicklow                    2    Jennifer       1321
# 373           Dublin West                    1       David       2795
# 374             Cork East                    3       David       2530
# 375             Tipperary                    0    Caroline       1179
# 376                Offaly                    3       Barry       2334
# 377           Galway West                    0        Sean       2538
# 378             Tipperary                    2      Jackie       1340
# 379                 Clare                    0         Pat       3362
# 380     Dublin South West                   43   Katherine       8468
# 381               Wicklow                    0      Sharon        129
# 382         Dublin Fingal                    0      Roslyn       1209
#
#      following                fullname  Twitter ID     last_tweet  \
# 0         1727  Fiona McLoughlin Healy   274437336      1 day ago
# 1         3042      Anne-Marie McNally   252591743      1 day ago
# 2          237           Derek Keating    95884790     5 days ago
# 3          841          Brian Finucane  1510303820     3 days ago
# 4          725              Eric Byrne   236487406     3 days ago
# 5          717           Arthur Spring   116559835     5 days ago
# 6         2162   Trevor O'Clochartaigh   238633165      1 day ago
# 7          238          Michael Gargan  4362566415      1 day ago
# 8         1927            Alan Coleman  1110233430     3 days ago
# 9            0           Donal Jackson   249114962    5 years ago
# 10         315        Jason Fitzgerald  2700948430  10 months ago
# 11        1102     Michael Fitzmaurice  2914205799     3 days ago
# 12         152      Maureen O'Sullivan   249347954      1 day ago
# 13         600            Thomas Gould  2535265746      1 day ago
# 14         682           Diana O'Dwyer  4018333522     2 days ago
# 15        1355       Aodhan O'Riordain   120117254     2 days ago
# 16         463            Mick Wallace   248801998      1 day ago
# 17         967        Michael McCarthy   238158030     2 days ago
# 18        1807              Mary White   307783437     2 days ago
# 19          95           Niamh Kennedy  2175955558     5 days ago
# 20        1061        Stephen Donnelly   237826875     2 days ago
# 21        1103       Micheal Callaghan  1672601316     3 days ago
# 22         797          Bernard Durkan   228774722     3 days ago
# 23        1690              Paul Kehoe   327886319     5 days ago
# 24         160          Richard Bruton   237376611     3 days ago
# 25         608        Michael McNamara   246966794     2 days ago
# 26           8              Ray Butler   258928062    5 years ago
# 27         309        Michael McDonagh  2996782307     2 days ago
# 28         646            Joan Collins   361335767     2 days ago
# 29        3769              John Lyons   233555616     2 days ago
# ..         ...                     ...         ...            ...
# 353        155           Malcolm Byrne    21875813     1 week ago
# 354        231            Declan Crowe   364776590    2 weeks ago
# 355        245               Ann Walsh  4284175223     2 days ago
# 356         20             Tony Murphy  2325157639     4 days ago
# 357        118            James Reilly   153563285     5 days ago
# 358        327              Ben Gilroy    42974146    1 month ago
# 359       4007         Kevin Humphreys    75995713     3 days ago
# 360        278            Dessie Ellis   430934081     2 days ago
# 361        283               Mick Duff   400311929     4 days ago
# 362        148         Shirley Griffin  4631566403     6 days ago
# 363       1348           Sarah Holland  2291081306     2 days ago
# 364        141        Sean O'Ferghaill  2433459918     6 days ago
# 365        834        Seamus McMenamin  2227119464     3 days ago
# 366        343            Pat Kavanagh    85433887   7 months ago
# 367        442          Mattie McGrath   121375039      1 day ago
# 368        864           Brendan Young   314208239     3 days ago
# 369        805                TJ Clare   207705679     2 days ago
# 370        146          Donal Corcoran  3091486702     2 days ago
# 371        689           Peadar Toibin    48667895      1 day ago
# 372       1554          Jennifer Cuffe    74509308     3 days ago
# 373       2378        David McGuinness    94835912     2 days ago
# 374        910           David Stanton   104578228      1 day ago
# 375       1864         Caroline Hofman   430573302   24 hours ago
# 376       1110             Barry Cowen   432054563     3 days ago
# 377        470               Sean Kyne   316306021     3 days ago
# 378       3910           Jackie Cahill  3091852973      1 day ago
# 379       1798               Pat Breen    29163101     3 days ago
# 380        767       Katherine Zappone   360540613     2 days ago
# 381        179           Sharon Briggs  1945376654    2 weeks ago
# 382        968           Roslyn Fuller    88297885     2 days ago
#
#              lastname  overall_follower_change                     party  \
# 0    McLoughlin Healy                       51                 Fine Gael
# 1             McNally                        0          Social Democrats
# 2             Keating                       90                 Fine Gael
# 3            Finucane                       43      People Before Profit
# 4               Byrne                       71                    Labour
# 5              Spring                       68                    Labour
# 6      O'Clochartaigh                      142                 Sinn Fein
# 7              Gargan                       47                     Renua
# 8             Coleman                      142         Independent/Other
# 9             Jackson                        2         Independent/Other
# 10         Fitzgerald                        2                     Renua
# 11        Fitzmaurice                      120         Independent/Other
# 12         O'Sullivan                      312         Independent/Other
# 13              Gould                      102                 Sinn Fein
# 14            O'Dwyer                      132         Independent/Other
# 15          O'Riordan                      729                    Labour
# 16            Wallace                      907         Independent/Other
# 17           McCarthy                      100                    Labour
# 18              White                      160               Fianna Fail
# 19            Kennedy                       77         Independent/Other
# 20           Donnelly                     3931          Social Democrats
# 21          Callaghan                       50               Green Party
# 22             Durkan                      108                 Fine Gael
# 23              Kehoe                       67                 Fine Gael
# 24             Bruton                      318                 Fine Gael
# 25           McNamara                       60                    Labour
# 26             Butler                       18                 Fine Gael
# 27           McDonagh                       96               Fianna Fail
# 28            Collins                      449         Independent/Other
# 29              Lyons                      362                    Labour
# ..                ...                      ...                       ...
# 353             Byrne                       90               Fianna Fail
# 354             Crowe                        2         Independent/Other
# 355             Walsh                      107               Green Party
# 356            Murphy                       25         Independent/Other
# 357            Reilly                      181                 Fine Gael
# 358            Gilroy                       38  Direct Democracy Ireland
# 359         Humphreys                      324                    Labour
# 360             Ellis                      142                 Sinn Fein
# 361              Duff                       53                    Labour
# 362           Griffin                       12         Independent/Other
# 363           Holland                      431                 Sinn Fein
# 364      O'Fearghaill                       79               Fianna Fail
# 365         McMenamin                       70               Green Party
# 366          Kavanagh                        2         Independent/Other
# 367           McGrath                      168         Independent/Other
# 368             Young                       57         Independent/Other
# 369             Clare                      115         Independent/Other
# 370          Corcoran                       34                     Renua
# 371              Tibn                      327                 Sinn Fein
# 372             Cuffe                      187               Fianna Fail
# 373        McGuinness                       94         Independent/Other
# 374           Stanton                       62                 Fine Gael
# 375            Hofman                      -10         Independent/Other
# 376             Cowen                      195               Fianna Fail
# 377              Kyne                      202                 Fine Gael
# 378            Cahill                      301               Fianna Fail
# 379             Breen                       90                 Fine Gael
# 380           Zappone                      837         Independent/Other
# 381            Briggs                       53      People Before Profit
# 382            Fuller                      134         Independent/Other
#
#          screen_name  tweets
# 0         fionamacky    6359
# 1         amomcnally   21353
# 2       derekkeating     427
# 3      finucanebrian     973
# 4        ericbyrnetd     480
# 5           springaj    1391
# 6         trevorocsf    2531
# 7       mgarganrenua     742
# 8    alancolemancork     665
# 9    donaljacksonirl       1
# 10   3873b448ef1b4ac      49
# 11   michaelfitzmau1     184
# 12      mosullivantd    2369
# 13     thomasgouldsf     299
# 14    dianaodwyeraaa     408
# 15   aodhanoriordain   18500
# 16       wallacemick    3126
# 17       mmccarthytd    8247
# 18      senmarywhite    1077
# 19     kennedyniamhm      79
# 20   donnellystephen    4266
# 21   micheal_sustain     686
# 22   bernarddurkantd    1013
# 23    campaign4kehoe    1951
# 24   richardbrutontd    1822
# 25   mmcnamara_clare     576
# 26       raybutlertd       2
# 27    mcdonagh4clare     703
# 28     joancollinstd    2887
# 29       johnlyonstd    4258
# ..               ...     ...
# 353     malcolmbyrne      30
# 354     declancrowe1      95
# 355    annwalshgreen     468
# 356    tmurphyfingal     190
# 357    drjamesreilly     604
# 358        bengilroy    1141
# 359     khumphreystd    3524
# 360    dessieellistd     960
# 361           mduff3     256
# 362  shirley52806903      16
# 363    votehollandsf   12806
# 364   sofearghail_td     288
# 365  seamusmcmenamin    2520
# 366  cllrpatkavanagh     390
# 367  mattiemcgrathtd     733
# 368   brendanyoungkn     961
# 369      tj_clareind    1058
# 370       donalc2013     259
# 371          toibin1    5829
# 372      jenncuffe09     586
# 373   cllrmcguinness    6631
# 374   davidstantontd     695
# 375       cearuilinh   14198
# 376       cowenbarry     626
# 377       seankynetd    2778
# 378   jackiecahillff     817
# 379        patbreen1    1162
# 380  senatorkzappone    3652
# 381       shazzglazz     292
# 382     roslynfuller    1770
#
# [383 rows x 13 columns]

# %%
# Left merge on 'Twitter ID' - keeps all data from df1 and merge with corresponding data in df2
# Details of merging can be found here: http://pandas.pydata.org/pandas-docs/stable/merging.html

merged_df = pd.merge(df1, df2, how='left', on=['Twitter ID'])
merged_df.head(10)
# Out:
#     Twitter ID   Lastname  Firstname             Fullname  Gender  Party  \
# 0  5.07911e+08    Haughey       Sean         Sean Haughey    Male     ff
# 1  2.38613e+08    O'Leary      Julie        Julie O'Leary  Female     fg
# 2  2.05864e+07     Cannon     Ciaran        Ciaran Cannon    Male     fg
# 3  2.19454e+08    O'Brien  Johnathan     Jonathan O'Brien    Male     sf
# 4  1.97353e+07    Donohoe    Paschal      Paschal Donohoe    Male     fg
# 5            0    Quigley       Adam  Kiaran Adam Quigley    Male    ind
# 6            0      Leahy       John           John Leahy    Male  renua
# 7  2.07774e+07    Doherty       Gary         Gary Doherty    Male     sf
# 8  2.01068e+08      Hayde   Lorraine       Lorraine Hayde  Female    ind
# 9  2.91102e+07  McAuliffe       Paul       Paul McAuliffe    Male     ff
#
#          Constituency  Elected  OnTwitter        constituency   ...     \
# 0    Dublin Bay North        1          1    Dublin Bay North   ...
# 1  Cork North Central        0          1          Cork North   ...
# 2         Galway East        1          1         Galway East   ...
# 3  Cork North Central        1          1  Cork North Central   ...
# 4      Dublin Central        1          1      Dublin Central   ...
# 5   Dublin South West        0          0                 NaN   ...
# 6              Offaly        0          0                 NaN   ...
# 7             Donegal        0          1             Donegal   ...
# 8       Kildare South        0          1       Kildare South   ...
# 9   Dublin North West        0          1   Dublin North West   ...
#
#    firstname followers  following          fullname   last_tweet   lastname  \
# 0       Sean    1589.0      437.0      Sean Haughey    1 day ago    Haughey
# 1      Julie     799.0      888.0     Julie O'Leary    1 day ago    O'Leary
# 2     Ciaran    6061.0     2609.0     Ciaran Cannon    1 day ago     Cannon
# 3  Johnathan    3943.0     1000.0  Jonathan O'Brien   2 days ago    O'Brien
# 4    Paschal   10484.0     1817.0   Paschal Donohoe    1 day ago    Donohoe
# 5        NaN       NaN        NaN               NaN          NaN        NaN
# 6        NaN       NaN        NaN               NaN          NaN        NaN
# 7       Gary     690.0      601.0      Gary Doherty   3 days ago    Doherty
# 8   Lorraine     113.0      228.0    Lorraine Hayde  1 month ago      Hayde
# 9       Paul    1684.0     1638.0    Paul McAuliffe   2 days ago  McAuliffe
#
#   overall_follower_change              party    screen_name   tweets
# 0                   206.0        Fianna Fail   sean_haughey   2160.0
# 1                   132.0          Fine Gael      julieolry   3246.0
# 2                   104.0          Fine Gael   ciarancannon  13132.0
# 3                   434.0          Sinn Fein     jobrien_sf   3305.0
# 4                   310.0          Fine Gael       paschald   7567.0
# 5                     NaN                NaN            NaN      NaN
# 6                     NaN                NaN            NaN      NaN
# 7                   103.0          Sinn Fein        garydoc   1412.0
# 8                     8.0  Independent/Other       lorhayde    514.0
# 9                    94.0        Fianna Fail  paulmcauliffe   3829.0
#
# [10 rows x 21 columns]

# %% [markdown]
# ### Drop duplicated columns

# %%
# There are 2 columns for party, first name, last name, full name and constituency data in the merged dataframe. 
# Keep the column that appear in the CSV file so that there are no null values (if a candidate is not on Twitter,
# it cannot be matched to any row in the json file and would therefore not be given a value for those columns)
merged_df = merged_df.drop('party', 1)
merged_df = merged_df.drop('firstname', 1)
merged_df = merged_df.drop('lastname', 1)
merged_df = merged_df.drop('fullname', 1)
merged_df = merged_df.drop('constituency', 1)
merged_df.head(10)
# Out:
#     Twitter ID   Lastname  Firstname             Fullname  Gender  Party  \
# 0  5.07911e+08    Haughey       Sean         Sean Haughey    Male     ff
# 1  2.38613e+08    O'Leary      Julie        Julie O'Leary  Female     fg
# 2  2.05864e+07     Cannon     Ciaran        Ciaran Cannon    Male     fg
# 3  2.19454e+08    O'Brien  Johnathan     Jonathan O'Brien    Male     sf
# 4  1.97353e+07    Donohoe    Paschal      Paschal Donohoe    Male     fg
# 5            0    Quigley       Adam  Kiaran Adam Quigley    Male    ind
# 6            0      Leahy       John           John Leahy    Male  renua
# 7  2.07774e+07    Doherty       Gary         Gary Doherty    Male     sf
# 8  2.01068e+08      Hayde   Lorraine       Lorraine Hayde  Female    ind
# 9  2.91102e+07  McAuliffe       Paul       Paul McAuliffe    Male     ff
#
#          Constituency  Elected  OnTwitter  day_follower_change  followers  \
# 0    Dublin Bay North        1          1                 11.0     1589.0
# 1  Cork North Central        0          1                 -2.0      799.0
# 2         Galway East        1          1                  0.0     6061.0
# 3  Cork North Central        1          1                 12.0     3943.0
# 4      Dublin Central        1          1                  5.0    10484.0
# 5   Dublin South West        0          0                  NaN        NaN
# 6              Offaly        0          0                  NaN        NaN
# 7             Donegal        0          1                  0.0      690.0
# 8       Kildare South        0          1                  0.0      113.0
# 9   Dublin North West        0          1                  0.0     1684.0
#
#    following   last_tweet  overall_follower_change    screen_name   tweets
# 0      437.0    1 day ago                    206.0   sean_haughey   2160.0
# 1      888.0    1 day ago                    132.0      julieolry   3246.0
# 2     2609.0    1 day ago                    104.0   ciarancannon  13132.0
# 3     1000.0   2 days ago                    434.0     jobrien_sf   3305.0
# 4     1817.0    1 day ago                    310.0       paschald   7567.0
# 5        NaN          NaN                      NaN            NaN      NaN
# 6        NaN          NaN                      NaN            NaN      NaN
# 7      601.0   3 days ago                    103.0        garydoc   1412.0
# 8      228.0  1 month ago                      8.0       lorhayde    514.0
# 9     1638.0   2 days ago                     94.0  paulmcauliffe   3829.0

# %% [markdown]
# ### First save the dataset

# %%
# Write the merged dataframe to a csv file
merged_df.to_csv('data_ge16-candidates-twitter-elected.csv', index=False)

# %%
## Reload for checking
# Show the first 10 rows in the resulting CSV file
df = pd.read_csv('data_ge16-candidates-twitter-elected.csv')
df.head(100)
# Out:
#       Twitter ID          Lastname  Firstname                   Fullname  \
# 0   5.079108e+08           Haughey       Sean               Sean Haughey
# 1   2.386130e+08           O'Leary      Julie              Julie O'Leary
# 2   2.058638e+07            Cannon     Ciaran              Ciaran Cannon
# 3   2.194540e+08           O'Brien  Johnathan           Jonathan O'Brien
# 4   1.973533e+07           Donohoe    Paschal            Paschal Donohoe
# 5   0.000000e+00           Quigley       Adam        Kiaran Adam Quigley
# 6   0.000000e+00             Leahy       John                 John Leahy
# 7   2.077740e+07           Doherty       Gary               Gary Doherty
# 8   2.010677e+08             Hayde   Lorraine             Lorraine Hayde
# 9   2.911022e+07         McAuliffe       Paul             Paul McAuliffe
# 10  5.244232e+08          Kelleher      Billy             Billy Kelleher
# 11  0.000000e+00             Power      Mailo                Mailo Power
# 12  0.000000e+00            Murphy     Eugene              Eugene Murphy
# 13  2.261929e+07        O'Tuathail      Niall           Niall O'Tuathail
# 14  3.196865e+08            Browne      James               james Browne
# 15  1.849219e+07           Lawless      James              James Lawless
# 16  3.278863e+08             Kehoe       Paul                 Paul Kehoe
# 17  1.909877e+08            Murphy  Catherine           Catherine Murphy
# 18  2.339194e+08          O'Mahony       John              John O'Mahony
# 19  3.433011e+09           Farrell       Anne               Anne Farrell
# 20  0.000000e+00            Durkin       Mike                Mike Durkin
# 21  7.798963e+07             Lynch   Kathleen             Kathleen Lynch
# 22  1.045782e+08           Stanton      David              David Stanton
# 23  0.000000e+00            Martin      Barry               Barry Martin
# 24  1.140079e+08            Martin    Micheal             Micheal Martin
# 25  3.123374e+09          O'Reilly     Louise            Louise O'Reilly
# 26  0.000000e+00           Sheehan   Margaret           Margaret Sheehan
# 27  4.297415e+07            Gilroy        Ben                 Ben Gilroy
# 28  2.274313e+08           O'Muiri     Naoise             Naoise O'Muiri
# 29  4.273652e+09           Smollen        Ken                Ken Smollen
# ..           ...               ...        ...                        ...
# 70  0.000000e+00           Fleming        Tom                Tom Fleming
# 71  2.190070e+08            Reilly    Kathryn             Kathryn Reilly
# 72  3.959462e+09             Kelly    Leonard              Leonard Kelly
# 73  1.461890e+07             Moran     Oliver               Oliver Moran
# 74  2.469174e+08             Curry     Nicola               Nicola Curry
# 75  3.800002e+07           McEntee      Helen              Helen McEntee
# 76  2.227385e+09          Rabbitte       Anne              Anne Rabbitte
# 77  0.000000e+00             Smyth      Niamh                Niamh Smyth
# 78  3.901964e+07           Higgins   Lorraine           Lorraine Higgins
# 79  2.823032e+09            Bailey      Maria               Maria Bailey
# 80  2.436323e+08         MacSharry       Marc             Marc MacSharry
# 81  2.744373e+08  McLoughlin Healy      Fiona     Fiona McLoughlin Healy
# 82  2.363779e+08      Boyd-Barrett    Richard       Richard Boyd Barrett
# 83  2.352318e+09       Carney Boud   Cathleen                Carney Boud
# 84  3.934791e+07            Cooney      Donna               Donal Cooney
# 85  2.227119e+09         McMenamin     Seamus           Seamus McMenamin
# 86  3.613358e+08           Collins       Joan               Joan Collins
# 87  1.165472e+08          Halligan       John              John Halligan
# 88  1.488725e+08          McDonald   Mary Lou          Mary Lou McDonald
# 89  1.718438e+08             Walsh       Noel                 Noel Walsh
# 90  2.292470e+07            D'Arcy    Michael             Michael D'Arcy
# 91  6.726815e+07          Calleary       Dara              Dara Calleary
# 92  2.111742e+07            Harris      Simon               Simon Harris
# 93  2.289556e+09            Conroy   Caroline            Caroline Conroy
# 94  0.000000e+00             Stagg      Emmet                Emmet Stagg
# 95  2.493480e+08        O'Sullivan    Maureen         Maureen O'Sullivan
# 96  2.914206e+09       Fitzmaurice    Michael        Michael Fitzmaurice
# 97  2.491150e+08           Jackson      Donal              Donal Jackson
# 98  2.403174e+08             Hogan       Paul                 Paul Hogan
# 99  0.000000e+00   Storey-Cosgrave  Alexander  Alexander Storey-Cosgrave
#
#     Gender    Party          Constituency  Elected  OnTwitter  \
# 0     Male       ff      Dublin Bay North        1          1
# 1   Female       fg    Cork North Central        0          1
# 2     Male       fg           Galway East        1          1
# 3     Male       sf    Cork North Central        1          1
# 4     Male       fg        Dublin Central        1          1
# 5     Male      ind     Dublin South West        0          0
# 6     Male    renua                Offaly        0          0
# 7     Male       sf               Donegal        0          1
# 8   Female      ind         Kildare South        0          1
# 9     Male       ff     Dublin North West        0          1
# 10    Male       ff    Cork North Central        1          1
# 11  Female    renua             Waterford        0          0
# 12    Male       ff      Roscommon Galway        1          0
# 13    Male       sd               Wicklow        0          1
# 14    Male       ff               Wexford        1          1
# 15    Male       ff         Kildare North        1          1
# 16    Male       fg               Wexford        1          1
# 17  Female       sd         Kildare North        1          1
# 18    Male       fg           Galway West        0          1
# 19  Female    renua      Roscommon Galway        0          1
# 20    Male       ff        Cavan Monaghan        0          0
# 21  Female      lab    Cork North Central        0          1
# 22    Male       fg             Cork East        1          1
# 23    Male  aaa-pbp         Dublin Fingal        0          0
# 24    Male       ff    Cork South Central        1          1
# 25  Female       sf         Dublin Fingal        1          1
# 26  Female       gp                  Mayo        0          0
# 27    Male      ddi            Meath East        0          1
# 28    Male       fg      Dublin Bay North        0          1
# 29    Male      ind                Offaly        0          1
# ..     ...      ...                   ...      ...        ...
# 70    Male      ind                 Kerry        0          0
# 71  Female       sf        Cavan Monaghan        0          1
# 72    Male       sd               Wexford        0          1
# 73    Male       gp    Cork North Central        0          1
# 74  Female      ind       Dublin Rathdown        0          1
# 75  Female       fg            Meath East        1          1
# 76  Female       ff           Galway East        1          1
# 77  Female       ff        Cavan Monaghan        1          0
# 78  Female      lab           Galway East        0          1
# 79  Female       fg         Dun Laoghaire        1          1
# 80    Male       ff         Sligo Leitrim        1          1
# 81  Female       fg         Kildare South        0          1
# 82    Male  aaa-pbp         Dun Laoghaire        1          1
# 83  Female       sf     Dublin North West        0          1
# 84  Female       gp      Dublin Bay North        0          1
# 85    Male       gp            Meath West        0          1
# 86  Female      ind  Dublin South Central        1          1
# 87    Male      ind             Waterford        1          1
# 88  Female       sf        Dublin Central        1          1
# 89    Male      ind       Carlow-Kilkenny        0          1
# 90    Male       fg               Wexford        1          1
# 91    Male       ff                  Mayo        1          1
# 92    Male       fg               Wicklow        1          1
# 93  Female       gp     Dublin North West        0          1
# 94    Male      lab         Kildare North        0          0
# 95  Female      ind        Dublin Central        1          1
# 96    Male      ind      Roscommon Galway        1          1
# 97    Male      ind    Longford Westmeath        0          1
# 98    Male       sf    Longford Westmeath        0          1
# 99    Male       gp       Limerick County        0          0
#
#     day_follower_change  followers  following    last_tweet  \
# 0                  11.0     1589.0      437.0     1 day ago
# 1                  -2.0      799.0      888.0     1 day ago
# 2                   0.0     6061.0     2609.0     1 day ago
# 3                  12.0     3943.0     1000.0    2 days ago
# 4                   5.0    10484.0     1817.0     1 day ago
# 5                   NaN        NaN        NaN           NaN
# 6                   NaN        NaN        NaN           NaN
# 7                   0.0      690.0      601.0    3 days ago
# 8                   0.0      113.0      228.0   1 month ago
# 9                   0.0     1684.0     1638.0    2 days ago
# 10                  4.0     3006.0      227.0    5 days ago
# 11                  NaN        NaN        NaN           NaN
# 12                  NaN        NaN        NaN           NaN
# 13                  4.0     1932.0     1720.0    2 days ago
# 14                  3.0      149.0       71.0    2 days ago
# 15                  3.0     2478.0     2208.0     1 day ago
# 16                  0.0     3982.0     1690.0    5 days ago
# 17                 27.0    13245.0     1421.0    2 days ago
# 18                  2.0     3681.0      344.0    5 days ago
# 19                  0.0      322.0      441.0     1 day ago
# 20                  NaN        NaN        NaN           NaN
# 21                  1.0     6967.0     1129.0    5 days ago
# 22                  3.0     2530.0      910.0     1 day ago
# 23                  NaN        NaN        NaN           NaN
# 24                 18.0    17439.0     1851.0    5 days ago
# 25                  4.0     1048.0      295.0     1 day ago
# 26                  NaN        NaN        NaN           NaN
# 27                  1.0     1560.0      327.0   1 month ago
# 28                  2.0     2107.0     1315.0    2 days ago
# 29                  0.0       38.0       56.0  3 months ago
# ..                  ...        ...        ...           ...
# 70                  NaN        NaN        NaN           NaN
# 71                  0.0     2995.0     2100.0    2 days ago
# 72                 -1.0      432.0      415.0    2 days ago
# 73                  1.0      553.0      495.0     1 day ago
# 74                  1.0      363.0      371.0   2 weeks ago
# 75                  2.0     3897.0      940.0    2 days ago
# 76                  7.0     1303.0     2388.0    2 days ago
# 77                  NaN        NaN        NaN           NaN
# 78                  4.0     4497.0     1332.0    2 days ago
# 79                  2.0      793.0      750.0     1 day ago
# 80                  2.0     1363.0      471.0     1 day ago
# 81                  0.0     1721.0     1727.0     1 day ago
# 82                 18.0    14290.0     1822.0     1 day ago
# 83                  0.0      575.0      243.0    2 days ago
# 84                  0.0     1036.0     2015.0    2 days ago
# 85                 -1.0      610.0      834.0    3 days ago
# 86                  8.0     4864.0      646.0    2 days ago
# 87                  4.0     2325.0      346.0     1 day ago
# 88                 18.0    26976.0      944.0    3 days ago
# 89                  0.0       46.0        8.0   4 years ago
# 90                  1.0      808.0      238.0     1 day ago
# 91                  7.0     6002.0     2265.0     1 day ago
# 92                  3.0    10086.0     2150.0    2 days ago
# 93                 -1.0      262.0      168.0     1 day ago
# 94                  NaN        NaN        NaN           NaN
# 95                 13.0     4217.0      152.0     1 day ago
# 96                  1.0      801.0     1102.0    3 days ago
# 97                  0.0       11.0        0.0   5 years ago
# 98                  3.0      187.0       46.0   5 years ago
# 99                  NaN        NaN        NaN           NaN
#
#     overall_follower_change      screen_name   tweets
# 0                     206.0     sean_haughey   2160.0
# 1                     132.0        julieolry   3246.0
# 2                     104.0     ciarancannon  13132.0
# 3                     434.0       jobrien_sf   3305.0
# 4                     310.0         paschald   7567.0
# 5                       NaN              NaN      NaN
# 6                       NaN              NaN      NaN
# 7                     103.0          garydoc   1412.0
# 8                       8.0         lorhayde    514.0
# 9                      94.0    paulmcauliffe   3829.0
# 10                    213.0  billykellehertd   1065.0
# 11                      NaN              NaN      NaN
# 12                      NaN              NaN      NaN
# 13                      0.0   niallotuathail   3429.0
# 14                     59.0  jamesforwexford     45.0
# 15                    129.0         lawlessj  16452.0
# 16                     67.0   campaign4kehoe   1951.0
# 17                      0.0     cathmurphytd   6485.0
# 18                    144.0    johnomahonytd   1148.0
# 19                     14.0        annerenua   2995.0
# 20                      NaN              NaN      NaN
# 21                    218.0  kathleenlynchtd    436.0
# 22                     62.0   davidstantontd    695.0
# 23                      NaN              NaN      NaN
# 24                   1690.0  michealmartintd    947.0
# 25                    293.0       loreillysf   2950.0
# 26                      NaN              NaN      NaN
# 27                     38.0        bengilroy   1141.0
# 28                     55.0     naoiseomuiri   2249.0
# 29                     13.0      ken_smollen      9.0
# ..                      ...              ...      ...
# 70                      NaN              NaN      NaN
# 71                    132.0    kathrynreilly   3268.0
# 72                    125.0   leonardkellyge    663.0
# 73                    149.0     oliver_moran   2646.0
# 74                      4.0     nicola_curry   1743.0
# 75                    191.0         hmcentee   1295.0
# 76                    221.0     annerabbitte   4159.0
# 77                      NaN              NaN      NaN
# 78                    171.0       lorhiggins   8919.0
# 79                    171.0    mariabaileyfg   1371.0
# 80                     96.0    marcmacsharry    701.0
# 81                     51.0       fionamacky   6359.0
# 82                   1742.0     rboydbarrett   3097.0
# 83                    132.0    catcarneyboud    539.0
# 84                    131.0    donna_cooney1   1982.0
# 85                     70.0  seamusmcmenamin   2520.0
# 86                    449.0    joancollinstd   2887.0
# 87                    153.0     johnhalligan   2355.0
# 88                   2146.0  maryloumcdonald   5227.0
# 89                      9.0       noelgwalsh     46.0
# 90                     54.0     michaeldarcy   2348.0
# 91                    255.0     daracalleary   5095.0
# 92                    360.0    simonharristd   7434.0
# 93                     93.0  caroline1conroy    493.0
# 94                      NaN              NaN      NaN
# 95                    312.0     mosullivantd   2369.0
# 96                    120.0  michaelfitzmau1    184.0
# 97                      2.0  donaljacksonirl      1.0
# 98                     12.0  cllrpaulhogansf     43.0
# 99                      NaN              NaN      NaN
#
# [100 rows x 16 columns]

# %% [markdown]
# ## Data First Understanding

# %%
# Check how many rows and columns this dataframe has
df.shape
# Out:
# (100, 16)

# %%
#How many rows?
df.shape[0]
# Out:
# 100

# %%
#How many columns?
df.shape[1]
# Out:
# 16

# %%
# Show first 10 rows of data frame
# The rows are indexed starting from 0
df.head(10)
# Out:
#     Twitter ID   Lastname  Firstname             Fullname  Gender  Party  \
# 0  507910843.0    Haughey       Sean         Sean Haughey    Male     ff
# 1  238613047.0    O'Leary      Julie        Julie O'Leary  Female     fg
# 2   20586381.0     Cannon     Ciaran        Ciaran Cannon    Male     fg
# 3  219454029.0    O'Brien  Johnathan     Jonathan O'Brien    Male     sf
# 4   19735329.0    Donohoe    Paschal      Paschal Donohoe    Male     fg
# 5          0.0    Quigley       Adam  Kiaran Adam Quigley    Male    ind
# 6          0.0      Leahy       John           John Leahy    Male  renua
# 7   20777397.0    Doherty       Gary         Gary Doherty    Male     sf
# 8  201067717.0      Hayde   Lorraine       Lorraine Hayde  Female    ind
# 9   29110219.0  McAuliffe       Paul       Paul McAuliffe    Male     ff
#
#          Constituency  Elected  OnTwitter  day_follower_change  followers  \
# 0    Dublin Bay North        1          1                 11.0     1589.0
# 1  Cork North Central        0          1                 -2.0      799.0
# 2         Galway East        1          1                  0.0     6061.0
# 3  Cork North Central        1          1                 12.0     3943.0
# 4      Dublin Central        1          1                  5.0    10484.0
# 5   Dublin South West        0          0                  NaN        NaN
# 6              Offaly        0          0                  NaN        NaN
# 7             Donegal        0          1                  0.0      690.0
# 8       Kildare South        0          1                  0.0      113.0
# 9   Dublin North West        0          1                  0.0     1684.0
#
#    following   last_tweet  overall_follower_change    screen_name   tweets
# 0      437.0    1 day ago                    206.0   sean_haughey   2160.0
# 1      888.0    1 day ago                    132.0      julieolry   3246.0
# 2     2609.0    1 day ago                    104.0   ciarancannon  13132.0
# 3     1000.0   2 days ago                    434.0     jobrien_sf   3305.0
# 4     1817.0    1 day ago                    310.0       paschald   7567.0
# 5        NaN          NaN                      NaN            NaN      NaN
# 6        NaN          NaN                      NaN            NaN      NaN
# 7      601.0   3 days ago                    103.0        garydoc   1412.0
# 8      228.0  1 month ago                      8.0       lorhayde    514.0
# 9     1638.0   2 days ago                     94.0  paulmcauliffe   3829.0

# %%
# Show the data types in each column.
# int64 and float64 are numeric columns.
# The pandas type 'object' stands for Python strings
# Columns mixing numbers and characters are automatically converted to type 'object'.
# Some of the type 'object' columns may be more appropriate as numeric/continuous or as categorical types.
# We first explore the data, then decide which columns should be treated as 'continuous' and which 
# should be treated as 'categorical'.
df.dtypes
# Out:
# Twitter ID                 float64
# Lastname                    object
# Firstname                   object
# Fullname                    object
# Gender                      object
# Party                       object
# Constituency                object
# Elected                      int64
# OnTwitter                    int64
# day_follower_change        float64
# followers                  float64
# following                  float64
# last_tweet                  object
# overall_follower_change    float64
# screen_name                 object
# tweets                     float64
# dtype: object

# %%
print("Feature, UniqueValues") 
for column in df.columns:
    print(column + " : " + str(len(df[column].unique())))

## There are 100 candidates and just 81 candidates have TW_ID
# Out:
# Feature, UniqueValues
# Twitter ID : 81
# Lastname : 94
# Firstname : 77
# Fullname : 100
# Gender : 2
# Party : 10
# Constituency : 37
# Elected : 2
# OnTwitter : 2
# day_follower_change : 17
# followers : 81
# following : 81
# last_tweet : 15
# overall_follower_change : 72
# screen_name : 81
# tweets : 80

# %%
# Turn the feature 'ID' from 'int64' to 'category' type
df['Twitter ID'] = df['Twitter ID'].astype('category')
df.dtypes
# Out:
# Twitter ID                 category
# Lastname                     object
# Firstname                    object
# Fullname                     object
# Gender                       object
# Party                        object
# Constituency                 object
# Elected                       int64
# OnTwitter                     int64
# day_follower_change         float64
# followers                   float64
# following                   float64
# last_tweet                   object
# overall_follower_change     float64
# screen_name                  object
# tweets                      float64
# dtype: object

# %% [markdown]
# ## Data Understanding: data quality report

# %% [markdown]
# ### Table with descriptive statistics for all the categorical features

# %%
#Select all columns of type 'object'
categorical_columns = list(df.select_dtypes(['object','category']).columns)

categorical_columns
# Out:
# ['Twitter ID',
#  'Lastname',
#  'Firstname',
#  'Fullname',
#  'Gender',
#  'Party',
#  'Constituency',
#  'last_tweet',
#  'screen_name']

# %%
# Convert data type to category for these columns
for column in categorical_columns:
    df[column] = df[column].astype('category')
df.dtypes
# Out:
# Twitter ID                 category
# Lastname                   category
# Firstname                  category
# Fullname                   category
# Gender                     category
# Party                      category
# Constituency               category
# Elected                       int64
# OnTwitter                     int64
# day_follower_change         float64
# followers                   float64
# following                   float64
# last_tweet                 category
# overall_follower_change     float64
# screen_name                category
# tweets                      float64
# dtype: object

# %%
# Save table with descriptive statistics for all the categorical features in CSV file
df.select_dtypes(['category']).describe().T.to_csv('tbl_categorical_descriptive_stats.csv')

# Print table
df.select_dtypes(['category']).describe().T
# Out:
#              count unique            top freq
# Twitter ID     100     81              0   20
# Lastname       100     94          Smyth    3
# Firstname      100     77           John    4
# Fullname       100    100   james Browne    1
# Gender         100      2           Male   63
# Party          100     10             fg   23
# Constituency   100     37  Dun Laoghaire    6
# last_tweet      80     14      1 day ago   25
# screen_name     80     80         smytho    1

# %% [markdown]
# ### Table with descriptive statistics for all the continuous features

# %%
#Keep only the numerical features. "Elected" and "OnTwitter" are binary 'int64' columns
continuous_columns = list(df.select_dtypes(['float64']).columns)

# Another way: select columns containing continuous data manually.
# continuous_columns = df[['day_follower_change','followers','following','overall_follower_change','tweets']].columns

continuous_columns
# Out:
# ['day_follower_change',
#  'followers',
#  'following',
#  'overall_follower_change',
#  'tweets']

# %%
type(continuous_columns)
# Out:
# list

# %%
# Save table with descriptive statistics for all the continuous features in CSV file
df[continuous_columns].describe().T.to_csv('tbl_continuous_descriptive_stats.csv')

# Print table
df[continuous_columns].describe().T
# Out:
#                          count       mean          std   min     25%     50%  \
# day_follower_change       80.0     3.2375     5.426713  -2.0    0.00     1.0
# followers                 80.0  3992.4125  6796.830115  11.0  522.75  1636.5
# following                 80.0   954.9125   823.910638   0.0  283.00   728.0
# overall_follower_change   80.0   235.9375   432.727890   0.0   53.25   122.5
# tweets                    80.0  2971.4375  4131.832011   1.0  483.50  1886.5
#
#                              75%      max
# day_follower_change         4.00     27.0
# followers                4040.75  44534.0
# following                1619.25   3437.0
# overall_follower_change   206.25   2189.0
# tweets                   3478.75  27592.0

# %% [markdown]
# ### Histograms for all continuous features

# %%
# Plot a histogram of the continuous features and save in a PDF file
# Color list can be found at: https://www.webucator.com/blog/2015/03/python-color-constants-module/
df[continuous_columns].hist(figsize=(15,15), color='#B22222',
                            alpha=0.7, rwidth=0.85)
plt.savefig('plt_continuous_histograms.pdf')

# %% [markdown]
# ### Box plots for all the continuous features

# %%
import seaborn as sns
# Plot box plots for all the continuous features and save in a PDF file
pp = PdfPages('plt_continuous_box_plots.pdf')
flierprops = dict(marker='o', markerfacecolor='green', markersize=10,linestyle='none')
for col in continuous_columns:
    f = df[col].plot(kind='box', figsize=(7,7),showfliers=True,flierprops=flierprops)
    pp.savefig(f.get_figure())
    plt.show()

pp.close()

# %% [markdown]
# ### Bar plots for all the categorical features

# %%
# Plot bar charts for all categorical features and save them in a single PDF file
pp = PdfPages('plt_categorical_bar_charts.pdf')

## NOTE: here we use the .copy to advoid the changing of "categorical_columns"
## if not, the "categorical_columns" will be changed.

printing_list_categorical_columns = categorical_columns.copy()
printing_list_categorical_columns.remove('Twitter ID')
printing_list_categorical_columns.remove('screen_name')

for column in printing_list_categorical_columns:
    f = df[column].value_counts().plot(kind='bar', title=column, figsize=(12,5))
    pp.savefig(f.get_figure())
    plt.show()

pp.close()

# %% [markdown]
# ## Data Understanding: data quality plan
#
# ### Irregular cardinality
#
# Categorical features can have irregular cardinality if the same value is entered several times with a different spelling for example. In the following cell, I check whether there are any values in the categorical features which are duplicated because
# of spelling mistakes or different input standards

# %%
# Check for irregular cardinality in categorical features. There could be same values spelled differently
print("Unique values for:\n- Gender:", pd.unique(df.Gender.ravel()))
print("\n- Constituency:", sorted(pd.unique(df.Constituency.ravel())))
print("\n- Elected:", sorted(pd.unique(df.Elected.ravel())))
print("\n- OnTwitter:", sorted(pd.unique(df.OnTwitter.ravel())))
print("\n- Party:", sorted(pd.unique(df.Party.ravel())))
print("\n- last_tweet:", pd.unique(df.last_tweet.ravel()))
# Out:
# Unique values for:
# - Gender: ['Male' 'Female']
#
# - Constituency: ['Carlow-Kilkenny', 'Cavan Monaghan', 'Clare', 'Cork East', 'Cork North Central', 'Cork North West', 'Cork South Central', 'Cork South West', 'Donegal', 'Dublin Bay North', 'Dublin Central', 'Dublin Fingal', 'Dublin North West', 'Dublin Rathdown', 'Dublin South Central', 'Dublin South West', 'Dublin West', 'Dun Laoghaire', 'Galway East', 'Galway West', 'Kerry', 'Kildare North', 'Kildare South', 'Limerick City', 'Limerick County', 'Longford Westmeath', 'Louth', 'Mayo', 'Meath East', 'Meath West', 'Offaly', 'Roscommon Galway', 'Sligo Leitrim', 'Tipperary', 'Waterford', 'Wexford', 'Wicklow']
#
# - Elected: [0, 1]
#
# - OnTwitter: [0, 1]
#
# - Party: ['aaa-pbp', 'ddi', 'ff', 'fg', 'gp', 'ind', 'lab', 'renua', 'sd', 'sf']
#
# - last_tweet: ['1 day ago' '2 days ago' nan '3 days ago' '1 month ago' '5 days ago'
#  '3 months ago' '2 years ago' '4 days ago' '3 weeks ago' '1 week ago'
#  '7 days ago' '2 weeks ago' '4 years ago' '5 years ago']

# %% [markdown]
# There are no values in the categorical features that is duplicated. The cardinality of those features is correct.

# %% [markdown]
# ### Null values
#
# In the following cell, I check for null values in the dataset.

# %%
# Check whether there are null values in the data where values would be expected
df.isnull().sum()
# Out:
# Twitter ID                  0
# Lastname                    0
# Firstname                   0
# Fullname                    0
# Gender                      0
# Party                       0
# Constituency                0
# Elected                     0
# OnTwitter                   0
# day_follower_change        20
# followers                  20
# following                  20
# last_tweet                 20
# overall_follower_change    20
# screen_name                20
# tweets                     20
# dtype: int64

# %% [markdown]
# here are null values in the dataset, they correspond to features regarding Twitter account information. 20 candidates do not have a Twitter account and therefore the values for these features are null for those candidates. There are no null values where a value would be expected.

# %% [markdown]
# ### Outliers (It is hard! To decice remove or not remove those samples)
# In the box plots produced above, there are a number of outliers for the followers, tweets, day_follower_change and overall_follower_change features.
# They could be error in the data or represent correct information. So in the following cells, I check who are the 5 candidates with the most followers, the highest rate of follower change and who tweet the most.

# %%
# In the box plot above, we can see that there are a number of outliers in the 'followers' feature. This could be
# an error or it could be due to the fact that the outlier is a candidate who is more famous or influential than other candidates.

# Find out the 5 candidates with the highest number of followers
df.sort_values(by='followers', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last').head(5)
# Out:
#      Twitter ID  Lastname Firstname           Fullname  Gender Party  \
# 39  135514272.0     Kenny      Enda         Enda Kenny    Male    fg
# 88  148872468.0  McDonald  Mary Lou  Mary Lou McDonald  Female    sf
# 33  118999126.0   Coveney     Simon      Simon Coveney    Male    fg
# 24  114007914.0    Martin   Micheal     Micheal Martin    Male    ff
# 48   77184360.0    Burton      Joan        Joan Burton  Female   lab
#
#           Constituency  Elected  OnTwitter  day_follower_change  followers  \
# 39                Mayo        1          1                 20.0    44534.0
# 88      Dublin Central        1          1                 18.0    26976.0
# 33  Cork South Central        1          1                  7.0    21845.0
# 24  Cork South Central        1          1                 18.0    17439.0
# 48         Dublin West        1          1                 11.0    15980.0
#
#     following  last_tweet  overall_follower_change      screen_name  tweets
# 39      560.0  5 days ago                   2189.0      endakennytd   431.0
# 88      944.0  3 days ago                   2146.0  maryloumcdonald  5227.0
# 33      600.0  3 days ago                    510.0     simoncoveney  3631.0
# 24     1851.0  5 days ago                   1690.0  michealmartintd   947.0
# 48      572.0  5 days ago                   1325.0       joanburton   947.0

# %% [markdown]
# The candidate who has the most followers is Enda Kenny and the top five candidates are very influential. It is expected that they would have more followers than other candidates, therefore the outliers for this features seem to have correct values.
# ==> Not delete

# %%
# Find the 5 candidates with the highest rate of overall follower change
df.sort_values(by='overall_follower_change', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last').head(5)
# Out:
#      Twitter ID      Lastname Firstname              Fullname  Gender  \
# 39  135514272.0         Kenny      Enda            Enda Kenny    Male
# 88  148872468.0      McDonald  Mary Lou     Mary Lou McDonald  Female
# 82  236377912.0  Boyd-Barrett   Richard  Richard Boyd Barrett    Male
# 24  114007914.0        Martin   Micheal        Micheal Martin    Male
# 48   77184360.0        Burton      Joan           Joan Burton  Female
#
#       Party        Constituency  Elected  OnTwitter  day_follower_change  \
# 39       fg                Mayo        1          1                 20.0
# 88       sf      Dublin Central        1          1                 18.0
# 82  aaa-pbp       Dun Laoghaire        1          1                 18.0
# 24       ff  Cork South Central        1          1                 18.0
# 48      lab         Dublin West        1          1                 11.0
#
#     followers  following  last_tweet  overall_follower_change  \
# 39    44534.0      560.0  5 days ago                   2189.0
# 88    26976.0      944.0  3 days ago                   2146.0
# 82    14290.0     1822.0   1 day ago                   1742.0
# 24    17439.0     1851.0  5 days ago                   1690.0
# 48    15980.0      572.0  5 days ago                   1325.0
#
#         screen_name  tweets
# 39      endakennytd   431.0
# 88  maryloumcdonald  5227.0
# 82     rboydbarrett  3097.0
# 24  michealmartintd   947.0
# 48       joanburton   947.0

# %%
# Find the 5 candidates with the highest rate of day follower change
df.sort_values(by='day_follower_change', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last').head(5)
# Out:
#      Twitter ID      Lastname  Firstname              Fullname  Gender  \
# 17  190987689.0        Murphy  Catherine      Catherine Murphy  Female
# 39  135514272.0         Kenny       Enda            Enda Kenny    Male
# 82  236377912.0  Boyd-Barrett    Richard  Richard Boyd Barrett    Male
# 24  114007914.0        Martin    Micheal        Micheal Martin    Male
# 88  148872468.0      McDonald   Mary Lou     Mary Lou McDonald  Female
#
#       Party        Constituency  Elected  OnTwitter  day_follower_change  \
# 17       sd       Kildare North        1          1                 27.0
# 39       fg                Mayo        1          1                 20.0
# 82  aaa-pbp       Dun Laoghaire        1          1                 18.0
# 24       ff  Cork South Central        1          1                 18.0
# 88       sf      Dublin Central        1          1                 18.0
#
#     followers  following  last_tweet  overall_follower_change  \
# 17    13245.0     1421.0  2 days ago                      0.0
# 39    44534.0      560.0  5 days ago                   2189.0
# 82    14290.0     1822.0   1 day ago                   1742.0
# 24    17439.0     1851.0  5 days ago                   1690.0
# 88    26976.0      944.0  3 days ago                   2146.0
#
#         screen_name  tweets
# 17     cathmurphytd  6485.0
# 39      endakennytd   431.0
# 82     rboydbarrett  3097.0
# 24  michealmartintd   947.0
# 88  maryloumcdonald  5227.0

# %% [markdown]
# The candidates who have the highest rate of overall follower change have a high number of followers (4 of them are in the top 5). They also correspond to candidates with a high daily follower change rate. The data therefore does not seem erroneous. ==> Not delete

# %%
# Find the 5 candidates with the most tweets
df.sort_values(by='tweets', axis=0, ascending=False, inplace=False, kind='quicksort', na_position='last').head(5)
# Out:
#      Twitter ID          Lastname Firstname                Fullname  Gender  \
# 55  180885830.0              Hunt     Carol              Carol Hunt  Female
# 15   18492194.0           Lawless     James           James Lawless    Male
# 2    20586381.0            Cannon    Ciaran           Ciaran Cannon    Male
# 66   92521829.0  Mitchell-OConnor      Mary  Mary Mitchell O'Connor  Female
# 78   39019643.0           Higgins  Lorraine        Lorraine Higgins  Female
#
#    Party   Constituency  Elected  OnTwitter  day_follower_change  followers  \
# 55   ind  Dun Laoghaire        0          1                  1.0     8113.0
# 15    ff  Kildare North        1          1                  3.0     2478.0
# 2     fg    Galway East        1          1                  0.0     6061.0
# 66    fg  Dun Laoghaire        1          1                  4.0     5707.0
# 78   lab    Galway East        0          1                  4.0     4497.0
#
#     following  last_tweet  overall_follower_change      screen_name   tweets
# 55     2680.0   1 day ago                    299.0       carolmhunt  27592.0
# 15     2208.0   1 day ago                    129.0         lawlessj  16452.0
# 2      2609.0   1 day ago                    104.0     ciarancannon  13132.0
# 66     2752.0   1 day ago                    157.0  mitchelloconnor   8989.0
# 78     1332.0  2 days ago                    171.0       lorhiggins   8919.0

# %% [markdown]
# The 5 candidates with the most tweets tweeted in the last couple of days. It is possible that they have a habit of twitting often. It is not possible to understand whether the data is correct or not. ==> Not delete

# %% [markdown]
# ### Duplicate rows
#
# In the following cell, I check for duplicate rows. It is important to eliminate duplicates so as not to skew the result of the analysis, so if one candidate appears in more than one row, it would be necessary to eliminate one of the rows.

# %%
# Checking for duplicated rows
print(df.set_index('Twitter ID').index.get_duplicates())
print(df.set_index('Fullname').index.get_duplicates())
print(df.set_index('screen_name').index.get_duplicates())
# Out:
# [0.0]
# []
# [nan]

# %% [markdown]
# There are no rows containing the same values for twitter ID, Fullname or screen_name, except for null values in Twitter ID and screen_name, suggesting that there are no duplicated candidates.

# %% [markdown]
# ## Solutions
#
# ### Data Quality Plan
#
# | Feature                 | Data Quality Issue   | Handling Strategy            |
# |-------------------------|----------------------|------------------------------|
# | day_follower_change     | Missing Values (20%) | Complete-case analysis       |
# | followers               | Missing Values (20%) | Complete-case analysis       |
# | following               | Missing Values (20%) | Complete-case analysis       |
# | last_tweet              | Missing Values (20%) | Complete-case analysis       |
# | overall_follower_change | Missing Values (20%) | Complete-case analysis       |
# | screen_name             | Missing Values (20%) | Complete-case analysis       |
# | tweets                  | Missing Values (20%) | Complete-case analysis       |
# | followers               | Outliers             | Do nothing                   |
# | day_follower_change     | Outliers             | Do nothing                   |
# | overall_follower_change | Outliers             | Do nothing                   |
# | tweets                  | Outliers             | Do nothing                   |
#
# I am **removing all rows containing null values, because they correspond to candidates who do not have a Twitter account.** The tasl for this problem is to 'look for initial evidence that candidate Twitter account details (e.g., tweets, folowers) is (or not) indicative of getting elected'. Therefore data relating to candidates who do not have a Twitter account is not relevant and would skew the result of the analysis. Dropping the features containing null values would affect the analysis because they correspond to the Twitter account details of the candidates. Imputation (replacing missing values with a measure of central tendency) would not be useful either because it would distort the data by putting too much weight on the mean, median or mode depending on which measure was chosen as a replacement.
#
# There are outliers in the followers, day_follower_change, overall_follower_change and tweets features. I have decided **not to remove the outliers** by clamping, because as shown above, the outliers for  followers, day_follower_change and overall_follower_change seem to be valid. Removing this data would probably modify the dataset to not reflect reality. It is not possible to verify the validity of the outliers in the tweets feature so I chose to be cautious and to accept them as being valid, and therefore to keep them in the dataset so as not to produce distorted data.

# %%
# Remove all rows for candidates who are not on Twitter - therefore all rows with null values
clean_df = df[df.OnTwitter == 1]
clean_df.head()
# Out:
#     Twitter ID Lastname  Firstname          Fullname  Gender Party  \
# 0  507910843.0  Haughey       Sean      Sean Haughey    Male    ff
# 1  238613047.0  O'Leary      Julie     Julie O'Leary  Female    fg
# 2   20586381.0   Cannon     Ciaran     Ciaran Cannon    Male    fg
# 3  219454029.0  O'Brien  Johnathan  Jonathan O'Brien    Male    sf
# 4   19735329.0  Donohoe    Paschal   Paschal Donohoe    Male    fg
#
#          Constituency  Elected  OnTwitter  day_follower_change  followers  \
# 0    Dublin Bay North        1          1                 11.0     1589.0
# 1  Cork North Central        0          1                 -2.0      799.0
# 2         Galway East        1          1                  0.0     6061.0
# 3  Cork North Central        1          1                 12.0     3943.0
# 4      Dublin Central        1          1                  5.0    10484.0
#
#    following  last_tweet  overall_follower_change   screen_name   tweets
# 0      437.0   1 day ago                    206.0  sean_haughey   2160.0
# 1      888.0   1 day ago                    132.0     julieolry   3246.0
# 2     2609.0   1 day ago                    104.0  ciarancannon  13132.0
# 3     1000.0  2 days ago                    434.0    jobrien_sf   3305.0
# 4     1817.0   1 day ago                    310.0      paschald   7567.0

# %%
# Check that there are no null values in the dataframe
print(clean_df.isnull().sum())

# check that only 20 rows have been removed (check that there are now 80 rows)
print("\nNumber of rows:", clean_df.shape[0])
# Out:
# Twitter ID                 0
# Lastname                   0
# Firstname                  0
# Fullname                   0
# Gender                     0
# Party                      0
# Constituency               0
# Elected                    0
# OnTwitter                  0
# day_follower_change        0
# followers                  0
# following                  0
# last_tweet                 0
# overall_follower_change    0
# screen_name                0
# tweets                     0
# dtype: int64
#
# Number of rows: 80

# %% [markdown]
# Now that rows for candidates who are not on Twitter have been removed, the feature OnTwitter should have a cardinality of 1. If this is the case, it can be removed as it is not useful.

# %%
# print unique values in OnTwitter column
print("\n- Unique values for OnTwitter:", pd.unique(clean_df.OnTwitter.ravel()))

# Remove OnTwitter column if there are only one unique value in OnTwitter
if(len(pd.unique(clean_df.OnTwitter.ravel())) == 1):
    clean_df = clean_df.drop('OnTwitter', 1)
# Out:
# - Unique values for OnTwitter: [1]

# %% [markdown]
# ## Save the Clean data

# %%
# Save cleaned dataframe to new CSV file
clean_df.to_csv('data_ge16-candidates-twitter-elected-clean.csv', index=False)

clean_df.head(1)
# Out:
#     Twitter ID Lastname Firstname      Fullname Gender Party  \
# 0  507910843.0  Haughey      Sean  Sean Haughey   Male    ff
#
#        Constituency  Elected  day_follower_change  followers  following  \
# 0  Dublin Bay North        1                 11.0     1589.0      437.0
#
#   last_tweet  overall_follower_change   screen_name  tweets
# 0  1 day ago                    206.0  sean_haughey  2160.0
