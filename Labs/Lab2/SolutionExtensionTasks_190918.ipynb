# %% [markdown]
# # Solution: Extension Task 1 & 2

# %%
# Import Libraries
import requests
import feedparser
from bs4 import BeautifulSoup
import json
import pandas as pd
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream

# %% [markdown]
# ## Task 01:

# %%
# Function to get data from HTML of IrishTimes
def getArticleDetailsByUrl(url):
    page = requests.get(url)
    soup = BeautifulSoup(page.text,"html.parser")
    #soup.prettify()
    
    headline = soup.title.string
    subheadline = soup.head.find("meta",attrs={"name":"description"}).get('content')

    doc_body = ''
    if "The Irish Times" in soup.text:
        for body_p_tag in soup.article.find_all("p", attrs={"class": "no_name"}):
            doc_body += body_p_tag.get_text() + " "

    source = "Other"
    try:
        if "irishtimes" in url:
            source = "IrishTimes"
            body_p_tag = soup.article.find("div", attrs={"class": "last_updated"}).find("p")
    except:
        pass

    first_sentence = doc_body.split(".")[0]

    return [headline, subheadline, first_sentence, doc_body, source]

# %%
# Parse the Irish RSSFeed
RSSfeed = feedparser.parse('http://www.irishtimes.com/cmlink/news-1.1319192')

indx = 1
df1 = pd.DataFrame([],columns=['Article_ID','Title','Content']) # dataframe to store data

for item in RSSfeed['entries']:
    article_url = item['link']
    [headline, subheadline, first_sentence, doc_body, source] = getArticleDetailsByUrl(article_url) 
    
    # Append data into dataframe
    df1 = df1.append({'Article_ID':int(indx), 'Title':headline, 'Content':doc_body},ignore_index=True)
    indx = indx + 1

# Set the index of dataframe into Article_ID
df1.set_index('Article_ID', inplace=True)
df1
# Out:
#                                                         Title  \
# Article_ID
# 1           TG4 apologises after CGI clip shows caravan ki...
# 2           Armed man commits robbery at Killiney Shopping...
# 3           Fisherman in court charged with murdering woma...
# 4           Detailed backstop proposals urgently needed, V...
# 5           Decision to prosecute woman over abortion pill...
# 6           City vacant: Dublin’s hundreds of multi-millio...
# 7           Potentially ‘nasty’ storm may hit Ireland this...
# 8              Bunny Carr, former RTÉ presenter, dies aged 91
# 9           Dundalk murder: Man (48) to appear in court ov...
# 10                  The dodgy science of wiping your backside
# 11          Tomorrow’s Garda recruits might progress on me...
# 12          Levies could raise €27m from vacant Dublin sit...
# 13          Gardaí in specialist units ‘not superior’ to l...
# 14          Plastic recycling must increase 80% by 2030 to...
# 15          Q&A;: Are ideas for Garda reform new or recycled?
# 16          Irish patients still pay for cuts introduced i...
# 17          New storm could strike this weekend, says Met ...
# 18          Consultants warn industrial action over two-ti...
# 19          ‘Irish Passport’ among most popular searches o...
# 20          Many trees in storm fell because of earlier dr...
#
#                                                       Content
# Article_ID
# 1           TG4 has apologised after a computer-generated ...
# 2           A robbery took place at Killiney Shopping Cent...
# 3           A 48-year-old man appeared in court in Dundalk...
# 4           The UK needs to put detailed proposals on the ...
# 5            The high court in Belfast is set to hear a le...
# 6           Almost 200 sites and properties worth millions...
# 7           Met Eireann is monitoring a weather front whic...
# 8           Bunny Carr, the former RTÉ presenter and found...
# 9           A man (48) is due to appear at Dundalk Distric...
# 10          Science is now a massive and expensive interna...
# 11          Recently a young Garda recruit was worrying wh...
# 12          More than €27 million could be raised by the f...
# 13          Community policing should become the main serv...
# 14          Ireland must increase its plastic packaging re...
# 15          Q: A new report from the Commission on the fut...
# 16          Irish patients are still paying the price for ...
# 17          Met Éireann is monitoring whether another stor...
# 18          The prospect of industrial action by consultan...
# 19          ‘Irish citizenship’ and ‘Irish passport’ were ...
# 20          Many trees that fell during Storm Ali were vul...

# %%
# Check the value again for dataframe:
print('Title of first news: \n', df1.iloc[0].Title)
print('Content of first news: \n', df1.iloc[0].Content)
# Out:
# Title of first news:
#  TG4 apologises after CGI clip shows caravan kicked off cliff
# Content of first news:
#  TG4 has apologised after a computer-generated imagery (CGI) clip broadcast before a news bulletin on Wednesday showed a caravan being kicked off a cliff into the sea.  On Wednesday a woman in her 50s was killed during Storm Ali, when a caravan she was staying in was swept off the coast by strong winds.  The woman, who has been named as Elvira Ferraii from Switzerland, was staying on her own in the caravan at the Clifden Eco Beach Camping and Caravan Park near Claddaghduff, Co Galway, when the incident occurred at about 7.45am. On Wednesday a TG4 clip depicted a scene of a giant creature carrying a caravan, before kicking it into the sea. The clip was shown before the 7pm Nuacht TG4 bulletin, which led with the news of Ms Ferraii’s death.  TG4 apologised for the clip, which it said ran on air only once on Wednesday.  “The ident [a broadcasting term which is short for station identification] is one of a series of six idents, running since 2013, which are auto-scheduled,” said a spokesman. “The ident [was] broadcast once yesterday and was immediately removed from the schedule. TG4 sincerely apologise for the unfortunate scheduling of this ident and any undue stress caused.”  The Irish language station said it had not received any complaints about the clip to date.

# %% [markdown]
# ## Task 02:

# %%
def getTweetData(filename):
    columns=['User_ID', 'User_name','Content', 'No_Retweets', 'User_Retweet']
    df = pd.DataFrame([],columns=columns) # dataframe to store data
    
    with open(filename) as file:
        all_tweets = map(json.loads, file.readlines()) # load each json line
        for single_tweet in all_tweets:
            user_id = single_tweet['user']['id']               # returns twitter user id
            user_name = single_tweet['user']['screen_name']    # returns twitter user name
            text = single_tweet['text']                        # returns content of tweet
            retweet_count = single_tweet['retweet_count']      # returns retweet count

            # Combine cases # returns retweeted user
            user_retweet =''
            if 'retweeted_status' in single_tweet:
                user_retweet = user_retweet + (single_tweet['retweeted_status']['user']['screen_name'])
            elif 'quoted_status' in single_tweet:
                user_retweet = user_retweet + " \nQ: " + single_tweet['quoted_status']['user']['screen_name']
            else:
                user_retweet = '<None>'
            
            # Append data into dataframe
            df = df.append({'User_ID':user_id, 
                            'User_name':user_name, 
                            'Content':text,
                            'No_Retweets':retweet_count,
                            'User_Retweet':user_retweet},ignore_index=True)
    return df

# %%
## Check function with 'twitter_search_100tweets.json'
df2 = getTweetData("twitter_search_100tweets.json")
df2.head(10)
# Out:
#                User_ID       User_name  \
# 0            417482440         Pvalsfr
# 1   981606042034372608    GDPR_for_SME
# 2            138054648     AaronNahale
# 3   930871517860319232   TheBigDataBot
# 4            138054648     AaronNahale
# 5            138054648     AaronNahale
# 6   772361408956731392   Manifattura40
# 7   769301256204541952  ThriveAmbition
# 8            260819964       freetoopt
# 9  1014177978215886848      AppliedAI1
#
#                                              Content No_Retweets  \
# 0  RT @gp_pulipaka: Time Series Forecasting Using...          29
# 1  RT @HarbRimah: Cybersecurity and Small Busines...          14
# 2  RT @kashthefuturist: Chinese police are using ...         145
# 3  RT @alison_iot: 🔭A #ContentMarketing Planning ...           9
# 4  RT @KirkDBorne: 50 Shades of Data:\n#AI\n#Anal...          39
# 5  RT @Fisher85M: Growth in the Internet of Thing...          10
# 6  RT @InsightBrief: What #DataScientists really ...           1
# 7  True Cost of Attrition: Why Good People Leave ...           0
# 8  RT @Ronald_vanLoon: 60+ Free Books on #BigData...           5
# 9  RT @Fisher85M: The Fields of #ArtificialIntell...          23
#
#       User_Retweet
# 0      gp_pulipaka
# 1        HarbRimah
# 2  kashthefuturist
# 3       alison_iot
# 4       KirkDBorne
# 5        Fisher85M
# 6     InsightBrief
# 7           <None>
# 8   Ronald_vanLoon
# 9        Fisher85M

# %%
## Check function with 'data_analytics_twitter_stream_10tweets.json'
df3 = getTweetData("data_analytics_twitter_stream_10tweets.json")
df3.head(10)
# Out:
#               User_ID       User_name  \
# 0           417482440         Pvalsfr
# 1  922987253286297600  gemini_finance
# 2  823520005706883072     Max_Lyashko
# 3  973110160163033088        Pain4200
# 4           206386815     supplychain
# 5  823520005706883072     Max_Lyashko
# 6            26833196         rlingle
# 7            64869385   Randumb_Rants
# 8            34377314       dorbendov
# 9  919744697551253505        akdm_bot
#
#                                              Content No_Retweets  \
# 0  RT @gp_pulipaka: Hybrid SDN of Industrial Inte...           0
# 1  How to get hired as a #datascientist - be proa...           0
# 2  RT @schmarzo: #EdgeAnalytics with #IoT environ...           0
# 3  RT @vg_fco: Harvard Business Review : The Key ...           0
# 4  The two are designing a new all-in-one invento...           0
# 5  RT @Fisher85M: Growth in the Internet of Thing...           0
# 6  Sharing trends in Big Data and Data Analytics ...           0
# 7  Simple, stupid ass manager + stupid trade dead...           0
# 8  Digital transformation: Amdocs Revenue Guard t...           0
# 9  RT @IBMSPSS: #ICYMI: 💪 💥 Discover this comic b...           0
#
#         User_Retweet
# 0        gp_pulipaka
# 1             <None>
# 2           schmarzo
# 3             vg_fco
# 4             <None>
# 5          Fisher85M
# 6             <None>
# 7   \nQ: phillysport
# 8             <None>
# 9            IBMSPSS
